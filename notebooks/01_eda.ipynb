# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.eda import *
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/raw/diamonds.csv', index_col=0)

df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
run_data_quality_report(df)
# Out:
# ...
# DATA QUALITY REPORT
# ...
# Shape: (53940, 10)
#
# Dtypes:
#  carat      float64
# cut            str
# color          str
# clarity        str
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object
#
# Missing values:
#          missing  missing_%
# carat          0        0.0
# cut            0        0.0
# color          0        0.0
# clarity        0        0.0
# depth          0        0.0
# table          0        0.0
# price          0        0.0
# x              0        0.0
# y              0        0.0
# z              0        0.0
#
# Duplicate rows: 146
#
# Constant columns:
# None

# %%
analyze_missing_values(df)
# Out:
# ...
# MISSING VALUES ANALYSIS
# ...
# Empty DataFrame
# Columns: [missing, missing_%]
# Index: []
# No missing values found.

# %%
analyze_numeric(df['carat'])
# Out:
# ...
# NUMERIC FEATURE: carat
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         273
#
# Statistics:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64
#
# Median:         0.7000
# Skewness:       1.1166
# Kurtosis:       1.2566

# %%
analyze_numeric(df['depth'])
# Out:
# ...
# NUMERIC FEATURE: depth
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         184
#
# Statistics:
# count    53940.000000
# mean        61.749405
# std          1.432621
# min         43.000000
# 25%         61.000000
# 50%         61.800000
# 75%         62.500000
# max         79.000000
# Name: depth, dtype: float64
#
# Median:         61.8000
# Skewness:       -0.0823
# Kurtosis:       5.7394

# %%
analyze_numeric(df['table'])
# Out:
# ...
# NUMERIC FEATURE: table
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         127
#
# Statistics:
# count    53940.000000
# mean        57.457184
# std          2.234491
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64
#
# Median:         57.0000
# Skewness:       0.7969
# Kurtosis:       2.8019

# %%
analyze_numeric(df['x'])
# Out:
# ...
# NUMERIC FEATURE: x
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         554
#
# Statistics:
# count    53940.000000
# mean         5.731157
# std          1.121761
# min          0.000000
# 25%          4.710000
# 50%          5.700000
# 75%          6.540000
# max         10.740000
# Name: x, dtype: float64
#
# Median:         5.7000
# Skewness:       0.3787
# Kurtosis:       -0.6182

# %%
analyze_numeric(df['y'])
# Out:
# ...
# NUMERIC FEATURE: y
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         552
#
# Statistics:
# count    53940.000000
# mean         5.734526
# std          1.142135
# min          0.000000
# 25%          4.720000
# 50%          5.710000
# 75%          6.540000
# max         58.900000
# Name: y, dtype: float64
#
# Median:         5.7100
# Skewness:       2.4342
# Kurtosis:       91.2146

# %%
analyze_numeric(df['z'])
# Out:
# ...
# NUMERIC FEATURE: z
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         375
#
# Statistics:
# count    53940.000000
# mean         3.538734
# std          0.705699
# min          0.000000
# 25%          2.910000
# 50%          3.530000
# 75%          4.040000
# max         31.800000
# Name: z, dtype: float64
#
# Median:         3.5300
# Skewness:       1.5224
# Kurtosis:       47.0866

# %%
analyze_categorical(df['cut'])
# Out:
# ...
# CATEGORICAL FEATURE: cut
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         5
#
# Top values:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64
#
# Top values (%):
# cut
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: proportion, dtype: float64

# %%
analyze_categorical(df['color'])
# Out:
# ...
# CATEGORICAL FEATURE: color
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         7
#
# Top values:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64
#
# Top values (%):
# color
# G    20.934372
# E    18.162773
# F    17.690026
# H    15.394883
# D    12.560252
# I    10.051910
# J     5.205784
# Name: proportion, dtype: float64

# %%
analyze_categorical(df['clarity'])
# Out:
# ...
# CATEGORICAL FEATURE: clarity
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         8
#
# Top values:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64
#
# Top values (%):
# clarity
# SI1     24.221357
# VS2     22.725250
# SI2     17.044865
# VS1     15.148313
# VVS2     9.391917
# VVS1     6.776047
# IF       3.318502
# I1       1.373749
# Name: proportion, dtype: float64

# %%
analyze_numeric(df['price'])
# Out:
# ...
# NUMERIC FEATURE: price
# ...
# Count:          53940
# Missing:        0
# Missing %:      0.00%
# Unique:         11602
#
# Statistics:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64
#
# Median:         2401.0000
# Skewness:       1.6184
# Kurtosis:       2.1777

# %%
plot_correlation_heatmap(df, target='price')

# %%
df.sort_values('x')
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 49557   0.71       Good     F     SI2   64.1   60.0   2130   0.00   0.00  0.00
# 26244   1.20    Premium     D    VVS1   62.1   59.0  15686   0.00   0.00  0.00
# 27430   2.25    Premium     H     SI2   62.8   59.0  18034   0.00   0.00  0.00
# 15952   1.14       Fair     G     VS1   57.5   67.0   6381   0.00   0.00  0.00
# 49558   0.71       Good     F     SI2   64.1   60.0   2130   0.00   0.00  0.00
# ...      ...        ...   ...     ...    ...    ...    ...    ...    ...   ...
# 26445   4.00  Very Good     I      I1   63.3   58.0  15984  10.01   9.94  6.31
# 26000   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25999   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27631   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27416   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# ...

# %%
analyze_target_relationship(df['cut'], df['price'])
# Out:
# ...
# cut -> price
# ...
#            count         mean
# cut
# Premium    13791  4584.257704
# Fair        1610  4358.757764
# Very Good  12082  3981.759891
# Good        4906  3928.864452
# Ideal      21551  3457.541970

# %%
analyze_target_relationship(df['color'], df['price'])
# Out:
# ...
# color -> price
# ...
#        count         mean
# color
# J       2808  5323.818020
# I       5422  5091.874954
# H       8304  4486.669196
# G      11292  3999.135671
# F       9542  3724.886397
# D       6775  3169.954096
# E       9797  3076.752475

# %%
analyze_target_relationship(df['clarity'], df['price'])
# Out:
# ...
# clarity -> price
# ...
#          count         mean
# clarity
# SI2       9194  5063.028606
# SI1      13065  3996.001148
# VS2      12258  3924.989395
# I1         741  3924.168691
# VS1       8171  3839.455391
# VVS2      5066  3283.737071
# IF        1790  2864.839106
# VVS1      3655  2523.114637
